# %% [markdown]
# # First ML Experiment – Linear Regression
#
# ## Research Question
# Can a simple linear regression model learn a relationship between input and output data?
#
# ## Hypothesis
# If the data has a linear relationship, a linear regression model should achieve low prediction error on unseen data.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Generate synthetic data
np.random.seed(42)
